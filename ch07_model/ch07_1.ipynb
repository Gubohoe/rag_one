# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\kbh\ex0917\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pip install langchain_community

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
from langchain_community.cache import SQLiteCache
import os

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo")

prompt = PromptTemplate.from_template("{country}에 대해서 200자 내외로 요약해줘")

chain = prompt | llm

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한반도 동쪽에 있는 대한민국은 아시아 동북부에 위치한 나라이다. 수도는 서울이며 인구는 약 5천만 명이 넘는다. 사회적으로는 자유민주주의를 기반으로 한 공화제를 가지고 있으며, 경제적으로는 선진국가로 발전하며 세계적으로 경제 강국으로 자리 잡았다. 문화적으로는 한류와 K-pop, K-drama 등이 세계적으로 인기를 끌며 한국 문화를 알리고 있다. 또한, 한국은 산업, 기술, 교육 등 다양한 분야에서 세계적인 업적을 이루고 있다. 그러나 분단된 한반도 상황으로 인해 북한과의 관계 등 몇몇 어려움과 과제도 가지고 있다.
# CPU times: total: 250 ms
# Wall time: 3.94 s

# %%
# %%time

set_llm_cache(InMemoryCache())

response2 = chain.invoke({"country": "한국"})
print(response2.content)
# Out:
# 한국은 동아시아에 위치한 나라로, 수도는 서울에 있다. 역사적으로는 고대 신라와 고려, 그리고 조선 시대를 거쳐 발전해왔다. 현대 한국은 세계적으로 경제 강국으로 발전하면서 K-pop, K-drama 등의 문화를 세계에 알리고 있다. 또한 한류 열풍으로 인해 한국 음식과 패션 등도 인기를 얻고 있다. 정치적으로는 대한민국과 북한이라는 두 나라로 분단되어 있으며, 이에 따른 긴장 관계와 통일을 위한 노력이 이어지고 있다. 한국은 고도의 ICT 기술과 높은 교육 수준을 바탕으로 미래 산업과 기술 발전을 선도하는 역할을 하고 있다.
# CPU times: total: 15.6 ms
# Wall time: 2.76 s

# %%
if not os.path.exists("cache"):
    os.makedirs("cache")

set_llm_cache(SQLiteCache(database_path="cache/llm_cache.db"))

# %%
# %%time
response3 = chain.invoke({"country": "한국"})
print(response3.content)
# Out:
# 한국은 동아시아에 위치한 반도 국가로, 수도는 서울에 위치해 있습니다. 한국은 5000년의 역사를 가진 문화 유산과 전통을 자랑하며, 한글이라는 독특한 문자체계를 사용합니다. 또한, 발전한 경제와 첨단 기술력을 보유하고 있으며 K-pop, K-drama와 같은 대중문화로 세계적으로 유명합니다. 주요 산업은 IT, 자동차, 조선, 화학 등이며, 한류 열풍과 함께 한국어 교육으로 세계적으로 유명해졌습니다. 또한, 한반도 분단 문제로 북한과의 관계가 주요 이슈로 다뤄지고 있습니다. 현재는 글로벌 국가로서 세계 각국과의 다양한 협력을 강화하며 발전하고 있는 중입니다.
# CPU times: total: 188 ms
# Wall time: 4.35 s
